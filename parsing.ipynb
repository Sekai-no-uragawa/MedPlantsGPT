# %%
from bs4 import BeautifulSoup
import requests

# %%
name = 'Леспедеца двуцветная'

# %%
url = 'https://www.plantarium.ru/page/view/item/2417.html'

# %%
page = requests.get(url)

# %%
print(page.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(page.text, "html.parser")

# %%
allTags = soup.findAll('p')

# %%
allTags
# Out:
# [<p>Вид на часть сазовой степи внутри станицы. У нас, такие места называют - Сага</p>,
#  <p>Чулекская балка расположена в охранной зоне Археологического музея-заповедника «Танаис», что определяет значимость памятника как природно-исторического объекта. Отличается высоким уровнем биоразнообразия и эндемизма. Флора составляет 350 видов сосудистых растений, среди которых 10 внесено в Красную книгу Ростовской области. Балка является центром обилия эндемика Приазовья – гиацинтика Палласа. Имеет природоохранное, научное и просветительское значение.</p>,
#  <p>Парк расположен на Аптекарском острове, между реками Карповка и Большая Невка. Это часть ботанического сада. В парке большая коллекция древесных интродуцентов. На горках,  коллекционных участках и цветниках выращивается множество видов травянистых растений, в том числе декоративных.</p>,
# ...

# %%
allTags[5].find('a').get('title') == 'Смотреть список видов этой Красной книги'
# Out:
# True

# %%
plants_redbooks = {}

# %%
plants_redbooks[name] = []
for tag in allTags:
    try:
        if tag.find('a').get('title') == 'Смотреть список видов этой Красной книги':
            link = tag.find('a').get('href')
            region = tag.text
            plants_redbooks[name].append((region, link))
    except:
        pass

# %%
plants_redbooks
# Out:
# {'Леспедеца двуцветная': [('Балтийский регион (1993)',
#    '/page/redbook/id/281.html'),
#   ('Республика Башкортостан (2001)', '/page/redbook/id/16.html'),
#   ('Республика Башкортостан (2011)', '/page/redbook/id/203.html'),
#   ('Брянская область (2004)', '/page/redbook/id/101.html'),
#   ('Брянская область (2016)', '/page/redbook/id/265.html'),
#   ('Грузинская ССР (1982)', '/page/redbook/id/92.html'),
#   ('Республика Калмыкия (2010)', '/page/redbook/id/107.html'),
#   ('Республика Калмыкия (2014)', '/page/redbook/id/201.html'),
#   ('Кемеровская область (2000)', '/page/redbook/id/49.html'),
#   ('Кемеровская область (2010)', '/page/redbook/id/95.html'),
#   ('Кемеровская область (2021)', '/page/redbook/id/304.html'),
#   ('Курганская область (2002)', '/page/redbook/id/68.html'),
#   ('Курганская область (2012)', '/page/redbook/id/222.html'),
#   ('Курская область (2002)', '/page/redbook/id/8.html'),
#   ('Курская область (2013)', '/page/redbook/id/122.html'),
# ...

# %%
list_of_links = [('Леспедеца двуцветная', 'https://www.plantarium.ru/page/view/item/22487.html', 1),
('Наперстянка шерстистая', 'https://www.plantarium.ru/page/view/item/13287.html', 0),
('Одуванчик лекарственный', 'https://www.plantarium.ru/page/view/item/37740.html', 1),
('Очиток большой', 'https://www.plantarium.ru/page/view/item/34967.html', 1),
('Пижма обыкновенная', 'https://www.plantarium.ru/page/view/item/37406.html', 1),
('Пион уклоняющийся', 'https://www.plantarium.ru/page/view/item/26648.html', 1),
('Пихта сибирская, белокорая', 'https://www.plantarium.ru/page/view/item/20.html', 0)]

# %%
import pickle

# %%
with open('data\plants.pickle', 'rb') as handle:
    list_of_links = pickle.load(handle)

# %%
list_of_links = [('Аир обыкновенный (болотный)',
  'https://www.plantarium.ru/page/view/item/664.html',
  1),
 ('Алтей лекарственный',
  'https://www.plantarium.ru/page/view/item/2417.html',
  1),
 ('Багульник болотный',
  'https://www.plantarium.ru/page/view/item/22241.html',
  1),
 ('Бадан толстолистный',
  'https://www.plantarium.ru/page/view/item/6418.html',
  1),
 ('Баранец обыкновенный',
  'https://www.plantarium.ru/page/view/item/20324.html',
  1),
 ('Бессмертник песчаный',
  'https://www.plantarium.ru/page/view/item/18366.html',
  1),
 ('Борец (аконит) белоустый',
  'https://www.plantarium.ru/page/samples/taxon/44226.html',
  1),
 ('Валериана лекарственная',
  'https://www.plantarium.ru/page/view/item/39858.html',
  1),
 ('Вахта трехлистная',
  'https://www.plantarium.ru/page/view/item/24291.html',
  1),
 ('Вздутоплодник сибирский',
  'https://www.plantarium.ru/page/view/item/27704.html',
  1),
 ('Володушка золотистая',
  'https://www.plantarium.ru/page/view/item/7158.html',
  1),
 ('Гамамелис виргинский',
  'https://www.plantarium.ru/page/view/item/46184.html',
  1),
 ('Дурман обыкновенный',
  'https://www.plantarium.ru/page/view/item/12728.html',
  1),
 ('Душица обыкновенная',
  'https://www.plantarium.ru/page/view/item/25797.html',
  1),
 ('Желтушник раскидистый',
  'https://www.plantarium.ru/page/view/item/71448.html',
  1),
 ('Жостер слабительный',
  'https://www.plantarium.ru/page/view/item/31639.html',
  1),
 ('Катарантус розовый',
  'https://www.plantarium.ru/page/view/item/45738.html',
  1),
 ('Копеечник альпийский',
  'https://www.plantarium.ru/page/view/item/18108.html',
  1),
 ('Крушина ольховидная',
  'https://www.plantarium.ru/page/view/item/16521.html',
  1),
 ('Лабазник вязолистный',
  'https://www.plantarium.ru/page/view/item/16470.html',
  1),
 ('Леспедеца двуцветная',
  'https://www.plantarium.ru/page/view/item/22487.html',
  1),
 ('Наперстянка шерстистая',
  'https://www.plantarium.ru/page/view/item/13287.html',
  0),
 ('Одуванчик лекарственный',
  'https://www.plantarium.ru/page/view/item/37740.html',
  1),
 ('Очиток большой', 'https://www.plantarium.ru/page/view/item/34967.html', 1),
 ('Пижма обыкновенная',
  'https://www.plantarium.ru/page/view/item/37406.html',
  1),
 ('Пион уклоняющийся',
  'https://www.plantarium.ru/page/view/item/26648.html',
  1),
 ('Пихта сибирская, белокорая',
  'https://www.plantarium.ru/page/view/item/20.html',
  0),
 ('Подорожник блошиный',
  'https://www.plantarium.ru/page/view/item/28614.html',
  1),
 ('Подофилл щитовидный',
  'https://www.plantarium.ru/page/view/item/47777.html',
  1),
 ('Полынь горькая', 'https://www.plantarium.ru/page/view/item/3793.html', 1),
 ('Пустырник сердечный',
  'https://www.plantarium.ru/page/view/item/22350.html',
  1),
 ('Родиола розовая', 'https://www.plantarium.ru/page/view/item/44512.html', 1),
 ('Синюха голубая', 'https://www.plantarium.ru/page/view/item/29149.html', 1),
 ('Скумпия кожевенная',
  'https://www.plantarium.ru/page/view/item/11420.html',
  1),
 ('Смоковница обыкновенная',
  'https://www.plantarium.ru/page/view/item/16413.html',
  1),
 ('Солодка голая', 'https://www.plantarium.ru/page/view/item/17684.html', 1),
 ('Сумах дубильный', 'https://www.plantarium.ru/page/view/item/44936.html', 1),
 ('Сушеница топяная',
  'https://www.plantarium.ru/page/view/item/17714.html',
  1),
 ('Термопсис ланцетный',
  'https://www.plantarium.ru/page/view/item/38164.html',
  1),
 ('Тимьян обыкновенный',
  'https://www.plantarium.ru/page/view/item/59252.html',
  1),
 ('Тмин обыкновенный',
  'https://www.plantarium.ru/page/view/item/9207.html',
  1),
 ('Толокнянка обыкновенная',
  'https://www.plantarium.ru/page/view/item/3573.html',
  1),
 ('Тыква обыкновенная',
  'https://www.plantarium.ru/page/view/item/12175.html',
  1),
 ('Тысячелистник обыкновенный',
  'https://www.plantarium.ru/page/view/item/319.html',
  1),
 ('Фенхель обыкновенный',
  'https://www.plantarium.ru/page/view/item/16499.html',
  1),
 ('Фиалка трехцветная',
  'https://www.plantarium.ru/page/view/item/40811.html',
  1),
 ('Хвощ полевой', 'https://www.plantarium.ru/page/view/item/14673.html', 1),
 ('Хмель обыкновенный',
  'https://www.plantarium.ru/page/view/item/20316.html',
  1),
 ('Тимьян ползучий', 'https://www.plantarium.ru/page/view/item/38454.html', 1),
 ('Чемерица лобеля', 'https://www.plantarium.ru/page/view/item/39977.html', 1),
 ('Череда трехраздельная',
  'https://www.plantarium.ru/page/view/item/6663.html',
  1),
 ('Чистотел большой',
  'https://www.plantarium.ru/page/view/item/10130.html',
  1),
 ('Шалфей лекарственны',
  'https://www.plantarium.ru/page/view/item/33522.html',
  1),
 ('Шиповник майский',
  'https://www.plantarium.ru/page/view/item/32327.html',
  1),
 ('Шлемник байкальский',
  'https://www.plantarium.ru/page/view/item/34695.html',
  1),
 ('Щавель конский', 'https://www.plantarium.ru/page/view/item/32758.html', 1),
 ('Якорцы стелющиеся', 'https://www.plantarium.ru/page/view/item/38895.html', 1)]

# %%
for name, url, _ in list_of_links:
    if url:
        page = requests.get(url)
        if page.status_code == 200:
            soup = BeautifulSoup(page.text, "html.parser")
            allTags = soup.findAll('p')
            plants_redbooks[name] = []
            for tag in allTags:
                try:
                    if tag.find('a').get('title') == 'Смотреть список видов этой Красной книги':
                        link = tag.find('a').get('href')
                        region = tag.text
                        plants_redbooks[name].append((region, link))
                except:
                    pass
        else:
            
            print(f'Ошибка соединения с {url, name}')

# %%
plants_redbooks
# Out:
# {'Леспедеца двуцветная': [('Забайкальский край (2014)',
#    '/page/redbook/id/231.html'),
#   ('Забайкальский край (2016)', '/page/redbook/id/275.html'),
#   ('Читинская область (2002)', '/page/redbook/id/105.html')],
#  'Наперстянка шерстистая': [('Республика Молдова (2002)',
#    '/page/redbook/id/57.html'),
#   ('Республика Молдова (2015)', '/page/redbook/id/243.html'),
#   ('СССР (1975)', '/page/redbook/id/239.html'),
#   ('СССР (1978)', '/page/redbook/id/128.html'),
#   ('СССР (1984)', '/page/redbook/id/125.html')],
#  'Одуванчик лекарственный': [],
#  'Очиток большой': [('Вологодская область (2004)', '/page/redbook/id/21.html'),
#   ('Вологодская область (2015)', '/page/redbook/id/230.html'),
#   ('Костромская область (2019)', '/page/redbook/id/296.html'),
#   ('Украина, Львовская область (2015)', '/page/redbook/id/250.html')],
#  'Пижма обыкновенная': [('Чеченская Республика (2007)',
#    '/page/redbook/id/118.html'),
# ...

# %%
clear_plants_redbooks = {}
for key, value in plants_redbooks.items():
    new_val = []
    for val in value:
        new_val.append((val[0].split('(')[0].strip(), val[1]))
    clear_plants_redbooks[key] = new_val

# %%
clear_plants_redbooks
# Out:
# {'Леспедеца двуцветная': [('Забайкальский край', '/page/redbook/id/231.html'),
#   ('Забайкальский край', '/page/redbook/id/275.html'),
#   ('Читинская область', '/page/redbook/id/105.html')],
#  'Наперстянка шерстистая': [('Республика Молдова', '/page/redbook/id/57.html'),
#   ('Республика Молдова', '/page/redbook/id/243.html'),
#   ('СССР', '/page/redbook/id/239.html'),
#   ('СССР', '/page/redbook/id/128.html'),
#   ('СССР', '/page/redbook/id/125.html')],
#  'Одуванчик лекарственный': [],
#  'Очиток большой': [('Вологодская область', '/page/redbook/id/21.html'),
#   ('Вологодская область', '/page/redbook/id/230.html'),
#   ('Костромская область', '/page/redbook/id/296.html'),
#   ('Украина, Львовская область', '/page/redbook/id/250.html')],
#  'Пижма обыкновенная': [('Чеченская Республика', '/page/redbook/id/118.html'),
#   ('Чеченская Республика', '/page/redbook/id/315.html')],
#  'Пион уклоняющийся': [('Архангельская область', '/page/redbook/id/37.html'),
# ...

# %%
results = {}
for key, value in clear_plants_redbooks.items():
    filtered_data = {}
    for item in value:
        region, link = item
        filtered_data[region] = link

    results[key] = list(filtered_data.items())

# %%
results
# Out:
# {'Леспедеца двуцветная': [('Забайкальский край', '/page/redbook/id/275.html'),
#   ('Читинская область', '/page/redbook/id/105.html')],
#  'Наперстянка шерстистая': [('Республика Молдова',
#    '/page/redbook/id/243.html'),
#   ('СССР', '/page/redbook/id/125.html')],
#  'Одуванчик лекарственный': [],
#  'Очиток большой': [('Вологодская область', '/page/redbook/id/230.html'),
#   ('Костромская область', '/page/redbook/id/296.html'),
#   ('Украина, Львовская область', '/page/redbook/id/250.html')],
#  'Пижма обыкновенная': [('Чеченская Республика', '/page/redbook/id/315.html')],
#  'Пион уклоняющийся': [('Архангельская область', '/page/redbook/id/301.html'),
#   ('Республика Башкортостан', '/page/redbook/id/203.html'),
#   ('Республика Бурятия', '/page/redbook/id/121.html'),
#   ('Бурятская АССР', '/page/redbook/id/24.html'),
#   ('Восточная Фенноскандия', '/page/redbook/id/55.html'),
#   ('Забайкальский край', '/page/redbook/id/275.html'),
# ...

# %%
import os
os.environ['OPENAI_API_KEY'] = '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'

# %%
import guidance

# set the default language model used to execute guidance programs
guidance.llm = guidance.llms.OpenAI("text-davinci-003")

# define a guidance program that adapts a proverb
program = guidance("""Tweak this proverb to apply to model instructions instead.

{{proverb}}
- {{book}} {{chapter}}:{{verse}}

UPDATED
Where there is no guidance{{gen 'rewrite' stop="\\n-"}}
- GPT {{gen 'chapter'}}:{{gen 'verse'}}""")

# execute the program on a specific proverb
executed_program = program(
    proverb="Where there is no guidance, a people falls,\nbut in an abundance of counselors there is safety.",
    book="Proverbs",
    chapter=11,
    verse=14
)
# Out:
# <div id="guidance-stop-button-87b9f120-d584-4632-be3a-c2c8b064b96a" style="cursor: pointer; margin: 0px; display: none; float: right; padding: 3px; border-radius: 4px 4px 4px 4px; border: 0px solid rgba(127, 127, 127, 1); padding-left: 10px; padding-right: 10px; font-size: 13px; background-color: rgba(127, 127, 127, 0.25);">Stop program</div><div id="guidance-content-87b9f120-d584-4632-be3a-c2c8b064b96a"><pre style='margin: 0px; padding: 0px; padding-left: 8px; margin-left: -8px; border-radius: 0px; border-left: 1px solid rgba(127, 127, 127, 0.2); white-space: pre-wrap; font-family: ColfaxAI, Arial; font-size: 15px; line-height: 23px;'>Tweak this proverb to apply to model instructions instead.
#
# <span style='background-color: rgba(0, 138.56128016, 250.76166089, 0.25); display: inline;' title='{{proverb}}'>Where there is no guidance, a people falls,
# but in an abundance of counselors there is safety.</span>
# ...

# %%
import yaml

with open('data\data.yml', 'w', encoding = 'utf-8') as outfile:
    yaml.dump(dict_doc, outfile, default_flow_style=False, allow_unicode=True)

# %%
with open("data\data.yml", "r", encoding='utf-8') as stream:
    try:
        a = yaml.safe_load(stream)
    except yaml.YAMLError as exc:
        print(exc)

# %%
a['АДЕНОСТИЛЕС РОМБОЛИСТНЫЙ']
# Out:
# ['  Травянистый  многолетник  высотой 50-150 (250) см. Корневище серовато-бурое, с рыхлой сердцевиной или полое, горизонтальное, длинное, ползучее, с поперечными рубцами от опавших чешуевидных листьев,  густо  усаженное  шнуровидными  придаточными  корнями.  Стебли  многочисленные,  голые,  темно-зеленые со слабым сизоватым налетом, ребристые, прямостоячие,  в  верхней  части  —  ветвистые,  полые. Листья  очередные,  черешковые,  треугольно-почковидные  или  широкояйцевидные,  коротко-  и  рассеянноопушенные,  у  основания  глубоковыемчатые,  нередко сердцевидно-стреловидные, по краю неравнозубчатые. Прикорневые листья длиной до 30 см, с длинными черешками;  стеблевые  листья  уменьшаются  к  верхушке стебля, черешки их у основания без ушек или с ушками; верхние листья длиной 1-8 см, почти сидячие, эллиптические или ланцетовидные, при основании оттянутые. На  концах  стеблей  и  их  разветвлений  расположены щитковидно-метельчатые соцветия, образованные многочисленными  мелкими  кор
# ...

# %%
text = ' '.join(a['АДЕНОСТИЛЕС РОМБОЛИСТНЫЙ'])

# %%
a['АДЕНОСТИЛЕС РОМБОЛИСТНЫЙ'][0]
# Out:
# '  Травянистый  многолетник  высотой 50-150 (250) см. Корневище серовато-бурое, с рыхлой сердцевиной или полое, горизонтальное, длинное, ползучее, с поперечными рубцами от опавших чешуевидных листьев,  густо  усаженное  шнуровидными  придаточными  корнями.  Стебли  многочисленные,  голые,  темно-зеленые со слабым сизоватым налетом, ребристые, прямостоячие,  в  верхней  части  —  ветвистые,  полые. Листья  очередные,  черешковые,  треугольно-почковидные  или  широкояйцевидные,  коротко-  и  рассеянноопушенные,  у  основания  глубоковыемчатые,  нередко сердцевидно-стреловидные, по краю неравнозубчатые. Прикорневые листья длиной до 30 см, с длинными черешками;  стеблевые  листья  уменьшаются  к  верхушке стебля, черешки их у основания без ушек или с ушками; верхние листья длиной 1-8 см, почти сидячие, эллиптические или ланцетовидные, при основании оттянутые. На  концах  стеблей  и  их  разветвлений  расположены щитковидно-метельчатые соцветия, образованные многочисленными  мелкими  корз
# ...
